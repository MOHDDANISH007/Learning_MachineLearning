# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('./restaurant_practice.csv')
df.head()
# Out:
#    visit_id  gender smoker        day    time   order  bill_amount  tip waiter
# 0         1    Male    Yes     Monday  Dinner   Pizza         22.5  3.5   Alex
# 1         2  Female     No    Tuesday   Lunch  Burger         15.0  2.0   Sara
# 2         3    Male     No  Wednesday  Dinner   Pasta         18.0  2.5   Alex
# 3         4  Female    Yes   Thursday   Lunch   Salad         12.5  1.5    Tom
# 4         5    Male     No     Friday  Dinner   Steak         35.0  6.0   Sara

# %%
# 1️⃣ NUMERICAL → NUMERICAL (comes under EDA bivariate)
# Scatter Plot

sns.scatterplot(x='tip', y='bill_amount', data=df, hue='gender',  style='time')
# Out:
# <Axes: xlabel='tip', ylabel='bill_amount'>
