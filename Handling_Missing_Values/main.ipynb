# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



df = pd.read_csv(
    'https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day33-handling-mixed-variables/titanic.csv?raw=true'
)

df.head()
