# %%
# 1 opening file when it exist in the main folder


import numpy as np
import pandas as pd

df = pd.read_csv(r"C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/student.csv")
print(df)
# Out:
#     cgpa  package
# 0    5.1      2.4
# 1    5.3      2.8
# 2    5.5      3.1
# 3    5.7      3.0
# 4    5.8      3.2
# ..   ...      ...
# 94   5.7      3.1
# 95   6.7      4.6
# 96   7.7      6.3
# 97   8.7      9.1
# 98   9.7     17.5
#
# [99 rows x 2 columns]

# %%
# 2 getting the file data from the URL or Server

import requests

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
r = requests.get(url)
print(r.text)
# Out:
# Venezuela,SOUTH AMERICAAICAMERICANORTH AMERICA

# %%
import pandas as pd

# 1. if we using tsv file there is mostly chance data is separated by tabs , so must make sure it is tsv file

# df = pd.read_csv("placement_data.tsv")
# df = pd.read_csv("placement_data.tsv",sep="\t", header=1)
# df = pd.read_csv("placement_data.tsv", sep="\t")

# print(df)

#  2. if you want only limited columns like [placement_test_score]

# df = pd.read_csv(
#     "C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/LoanData.csv",
#     usecols=["Loan_ID", "Gender", "Married", "Education", "Loan_Status", "Credit_History"]
# )

# 3. skip rows

def skip_even_rows(index):
    return index % 2 == 0  # skip even rows

df = pd.read_csv(
    "C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/LoanData.csv",
    skiprows=skip_even_rows
)

df
# Out:
#    LP001    Male  Yes    0      Graduate   No    5000     0.1    150    1  \
# 0  LP003    Male  Yes    2  Not Graduate  Yes  4000.0  1800.0  120.0  0.0
# 1  LP005  Female  NaN    0      Graduate   No  3500.0     0.0  110.0  1.0
# 2  LP007    male  Yes    1      Graduate   No  4200.0     0.0  130.0  1.0
# 3  LP008  Female   No    0      graduate   No  3800.0     0.0  105.0  NaN
# 4  LP010     NaN  Yes    0      Graduate   No  4500.0     NaN  115.0  1.0
# 5  LP012  Female  Yes    2      Graduate  NaN  5200.0     0.0  160.0  NaN
# 6  LP014    Male  NaN   3+  Not Graduate  Yes  2000.0  1500.0    NaN  0.0
# 7  LP016    Male   No    0      Graduate   No     NaN     0.0    NaN  1.0
# 8  LP018    Male  Yes  NaN      Graduate   No  4100.0     0.0  125.0  1.0
# 9  LP020  Female  NaN    0      Graduate   No  3900.0     0.0    NaN  1.0
#
#        Urban  Y
# 0      Rural  N
# 1  Semiurban  Y
# 2      Urban  Y
# 3  Semiurban  Y
# 4      Urban  Y
# 5  Semiurban  Y
# 6      Rural  N
# ...

# %%
import pandas as pd

# 4. if you want to replace error in the file

# 5. if you want to change the encoding ,means if your file is not in utf-8(in normal english) then you can change it to utf-8

# df2 = pd.read_csv(
#     "C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/LoanData.csv",
#     sep=",",
#     encoding="utf-8",
#     error_bad_lines='False'   # replaces deprecated error_bad_lines

# df2 = pd.read_csv(
#     "C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/LoanData.csv",
#     sep=",",
#     encoding="utf-8",
#     on_bad_lines='skip'   # replaces deprecated error_bad_lines
# )




# 6.if you want to change the data type

df2 = pd.read_csv(
    "C:/Users/mohdd/OneDrive/Documents/Desktop/Learning_Machine_Learning/working_with_different_file/LoanData.csv",
    sep=",",
    encoding="utf-8",
    on_bad_lines='skip',   # replaces deprecated error_bad_lines
    # dtype={"Credit_History": int} # changes the data type make sure do this when your data doesn't have null value in your data set

)

df2["Credit_History"].fillna(df2["Credit_History"].mean(), inplace=True)

# Step 3: Convert to int safely
df2["Credit_History"] = df2["Credit_History"].astype(int)

print(df2["Credit_History"].head())
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Credit_History, dtype: int64
# C:\Users\mohdd\AppData\Local\Temp\ipykernel_14868\2252984733.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Credit_History"].fillna(df2["Credit_History"].mean(), inplace=True)

# %%
# 7. handling date and time

import pandas as pd

df3 = pd.read_csv(
    "sample_dates.csv",
    dtype={"Date": str}  # Treat the Date column as string
)

print(df3)
print(df3.dtypes)
# Out:
#    ID     Name        Date  Amount
# 0   1     John  2025-01-01     100
# 1   2    Alice  2025-01-05     150
# 2   3      Bob  2025-01-10     200
# 3   4      Eve  2025-01-15     250
# 4   5  Charlie  2025-01-20     300
# 5   6     Dave  2025-01-25     350
# 6   7    Frank  2025-02-01     400
# 7   8    Grace  2025-02-05     450
# 8   9   Hannah  2025-02-10     500
# 9  10      Ian  2025-02-15     550
# ID         int64
# Name      object
# Date      object
# Amount     int64
# dtype: object

# %%
df4 = pd.read_csv(
    "sample_dates.csv",
    parse_dates=["Date"]
)

df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Name    10 non-null     object
#  2   Date    10 non-null     datetime64[ns]
#  3   Amount  10 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 452.0+ bytes
